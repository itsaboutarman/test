# %% [markdown]
# <font face="B Mitra" size=4>
# <div dir=rtl align=center>
#
# <br>
# <img src="https://aut.ac.ir/templates/tmpl_modern01/images/logo_fa.png" alt="Amirkabir University Logo" width="100">
#
# <br>
# <font size=2>
# <b>دانشگاه صنعتی امیرکبیر - دانشکده ریاضی و علوم کامپیوتر</b>
# </font>
#
# <br>
# <font size=6>
# <b>گرافیک کامپیوتری</b>
# </font>
#
# <br>
# <hr/>
# <font size=6>
# <b>تمرین سوم</b>
# </font>
#
# <br>
# استاد: دکتر مصطفی شمسی
#
# <br>
# طراحان:‌ پویا برازنده، یاسمین تفکر، مهدی غیاثی
# <hr>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra" size=5>
# <div dir=rtl>
#
# <p>
# <font size=4>
# لطفا فایل نوت بوک نهایی را با الگوی زیر در سامانه کورسز آپلود کنید.
# </font>
# </p>
#
# <div dir=ltr>
# <font face="Times New Roman" size=4 dir=ltr>
# شماره دانشجویی_CG_HW3.ipynb
# </font>
# </div>
#
# </div>
#
# <div dir=rtl>
#
# <p align="justify">
# <font size=4 color="lightblue">
# در صورتی که فایل را به صورت لوکال باز‌ می‌کنید، از دستورات مناسب که در فایل تمرین سری اول وجود داشت جهت نمایش تصاویر استفاده کنید.
# </font>
# </div>
# </font>

# %% [markdown]
# <font face="B Mitra" size=4>
#
# <hr>
# <div dir="rtl">
#     <h3>کتابخانه‌های مورد نیاز</h3>
#     <p>صرفا سلول زیر را اجرا کنید</p>
# </div>
# </font>

# %%
import cv2
import requests
# from google.colab.patches import cv2_imshow
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

def read_image_from_url(url, flags=cv2.IMREAD_COLOR):
    response = requests.get(url)
    response.raise_for_status()
    img_array = np.array(bytearray(response.content), dtype=np.uint8)
    img = cv2.imdecode(img_array, flags)
    return img

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#     <h3>1. هیستوگرام</h3>
#         <p>هیستوگرام تصویر، که نموداری از توزیع شدت‌های روشنایی یا رنگ‌ها در یک تصویر است، ابزار مهمی برای درک اطلاعات مربوط به کنتراست و تعادل نور در تصویر می‌باشد. این اطلاعات به عکاسان و ویراستاران کمک می‌کند تا بهینه‌سازی های مورد نیاز بر روی تصاویر را شناسایی و اعمال کنند، و از این طریق کیفیت بصری نهایی تصویر را ارتقاء دهند.</p>
#         </font>
#         <font face="B Mitra" size=5 color='e74c3c'>
#         ابتدا هر تصویر را نمایش داده و سپس هیستوگرام را برای تصاویر رسم کرده و کنتراست روشنایی و رنج دینامیکی هر تصویر را تحلیل کنید.
#         </font>
#     </div>
# </font>

# %%
# Load the input image
image = read_image_from_url("https://i.ibb.co/JKD9YQS/sea.png")

#TODO: Show the image

# %%
#TODO: plot the histogram of the image

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %%
# Load the input image
image = read_image_from_url("https://i.ibb.co/HTn3gZx/img.jpg")

#TODO: Show the image

# %%
#TODO: plot the histogram of the image

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %%
# Load the input image
image = read_image_from_url("https://i.ibb.co/7C0HcYV/B.jpg")

#TODO: Show the image

# %%
#TODO: plot the histogram of the image

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             بهبود کنتراست در تصاویر به معنی افزایش تفاوت شدت‌های نوری بین نقاط تاریک و روشن آن است، که منجر به تصاویر واضح‌تر و با جزئیات بیشتر می‌شود. روش‌های مختلفی برای این منظور وجود دارد، از جمله استفاده از توابع تبدیل خطی که دامنه شدت‌های را گسترش می‌دهد و هیستوگرام تصویر را فراگیرتر می‌کند.
#             <br/>
#             <br/>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             با استفاده از توابع تبدیل خطی که در درس آموختید نگاتیو تصویر زیر را به تصویر مناسب تبدیل کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
# Load the input image
image = read_image_from_url("https://i.ibb.co/pnFJy5w/negative.png")

#TODO: Show the image(it is a color image)

# %%
#TODO: implement negative transformation

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام تصویر اولیه و نهایی را رسم کرده و تفاوت آن‌ها را تحلیل کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
#TODO: plot histograms

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3>2. تابع تبدیل شدت لگاریتمی</h3>
#          <p>تابع تبدیل لگاریتمی در پردازش تصاویر با تأکید بر نمایش جزئیات در ناحیه‌های تاریک استفاده می‌شود. این تبدیل با استفاده از لگاریتم، شدت‌های پایین تصویر را افزایش داده و کنتراست را در این نواحی بهبود می‌بخشد، منجر به آشکارسازی بهتر جزئیات می‌شود.
#          <br/><br/>
#          <font face="B Mitra" size=5 color='e74c3c'>
#     این تابع را بر روی تصویر زیر اعمال کرده و تصویر جدید را نمایش دهید.
#         </font>
#         </p>
#     </div>
# </font>

# %%
# Load the input image
image = read_image_from_url("https://i.ibb.co/2t2Z20K/house1.jpg", cv2.IMREAD_GRAYSCALE)
height, width = image.shape
image = cv2.resize(image, (width // 2, height // 2), interpolation=cv2.INTER_LINEAR)

#TODO: Show the image

# %%
#TODO: implement log transformation

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام تصویر اولیه و نهایی را رسم کرده و تفاوت آن‌ها را تحلیل کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
#TODO: plot histograms

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3>3. تابع تبدیل شدت ریشه دوم</h3>
#          <p>تابع تبدیل ریشه دوم در پردازش تصویر برای بهبود نمایش جزئیات در نواحی تاریک و کاهش اثر شدت‌های بسیار بالا استفاده می‌شود. این تبدیل با استفاده از ریشه دوم، شدت‌های پایین تصویر را افزایش داده و شدت‌های بالا را کاهش می‌دهد، که منجر به نمایش متعادل‌تر تصویر و آشکارسازی بهتر جزئیات در نواحی کم‌نور می‌شود. این تابع به صورت زیر تعریف می‌شود:<br>
# <math>
#     <msub>
#         <mi>V</mi>
#         <mi>out</mi>
#     </msub>
#     <mo>=</mo>
#     <mi>C</mi>
#     <mo>&#8730;</mo>
#     <msub>
#         <mi>V</mi>
#         <mi>in</mi>
#     </msub>
# </math>
#          <br/><br/>
#          <font face="B Mitra" size=5 color='e74c3c'>
#     این تابع را بر روی تصویر زیر اعمال کرده و تصویر جدید را نمایش دهید. مقدار <math>C</math> را طوری انتخاب کنید که به‌ازای مقدار ورودی 255 خروجی نیز 255 شود.
#         </font>
#         </p>
#     </div>
# </font>

# %%
#TODO: implement square root transformation

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام تصویر اولیه و نهایی را رسم کرده و تفاوت آن‌ها را تحلیل کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
#TODO: plot histograms

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4.5>
# <div dir=rtl>
# 4.
# فرض کنید یک تابع تبدیل شدت به صورت زیر تعریف شده باشد:
#
# $$
# s=T(r)
# $$
#
#
# که در آن (r) شدت ورودی و (s) شدت خروجی است.
#
# 1. توضیح دهید چرا اگر:
#
# $$
# \frac{dT(r)}{dr} > 1
# $$
#
#
# باشد، کنتراست ناحیه مربوطه افزایش پیدا می‌کند.
#
# 2. توضیح دهید چرا اگر:
#
# $$
# \frac{dT(r)}{dr} < 1
# $$
#
#
# باشد، کنتراست کاهش پیدا می‌کند.
#
# </font>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size="4">
#     <div dir="rtl">
#     <h3>5. تابع تبدیل شدت گاما</h3>
#         <p>
#             Gamma correction یا تصحیح گاما یک عملیات غیرخطی است که برای کدگذاری و رمزگشایی مقادیر روشنایی یا مقادیر سه‌بعدی در سیستم‌های ویدیویی یا تصاویر ثابت استفاده می‌شود. گاما کارکشن در ساده‌ترین حالت با استفاده از معادله‌ای به صورت زیر تعریف می‌شود:
#         </p>
#         <p>
#             <code>V<sub>out</sub> = C V<sub>in</sub><sup>&gamma;</sup></code>
#         </p>
#         <p>
#             که در آن مقدار ورودی غیر منفی V<sub>in</sub> به توان &gamma; رسانده شده و با ثابت C ضرب می‌شود تا مقدار خروجی V<sub>out</sub> به دست آید.
#         </p>
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             این تابع را مطابق با روش گفته شده در جزوه پیاده‌سازی کنید و سپس تابع را بر روی تصویر اعمال کرده و تصویر جدید را نمایش دهید.
#             <br>
#             مقدار مناسب برای پارامتر گاما توسط شما باید انتخاب شود. (مقدار دقیق مدنظر نبوده و تنها باید مقداری انتخاب شود که سبب بهبود تصویر شود.)
#         </p>
#             </font>
#     </div>
# </font>

# %%
#TODO: implement gamma transformation

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام تصویر اولیه و نهایی را رسم کرده و تفاوت آن‌ها را تحلیل کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
#TODO: plot histograms

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size="4">
#     <div dir="rtl">
#     <h3>6. ترکیب دو تبدیل گاما (Cascading Gamma Transforms)</h3>
#     </div>
# </font>
#
# <font face="B Mitra" size="4">
# <div dir="rtl">
# <h4>الف) اثبات ریاضی</h4>
# <p>
# <font face="B Mitra" size=5 color='e74c3c'>
# نشان دهید که اعمال متوالی دو تبدیل گاما با ثابت‌های مناسب، معادل یک تبدیل گاما با
# <code>&gamma; = &gamma;<sub>1</sub> &sdot; &gamma;<sub>2</sub></code>
# است.
# </font>
# </p>
# <p>
# <font face="B Mitra" size=4 color='lightgreen'>
# <b>راهنمایی:</b> فرض کنید تبدیل گامای اول به صورت
# <code>V<sub>1</sub> = V<sub>in</sub><sup>&gamma;<sub>1</sub></sup></code>
# و تبدیل گامای دوم به صورت
# <code>V<sub>out</sub> = V<sub>1</sub><sup>&gamma;<sub>2</sub></sup></code>
# تعریف شود. با جایگذاری خروجی تبدیل اول در ورودی تبدیل دوم، نشان دهید که نتیجه نهایی برابر است با:
# <code>V<sub>out</sub> = V<sub>in</sub><sup>&gamma;<sub>1</sub> &sdot; &gamma;<sub>2</sub></sup></code>
# </p>
# </div>
# </font>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size="4">
# <div dir="rtl">
# <h4>ب) پیاده‌سازی و مقایسه</h4>
# <p>
# تابعی بنویسید که دو تبدیل گاما را به صورت متوالی روی تصویر اعمال کند (ابتدا با
# <code>&gamma;<sub>1</sub></code>
# و سپس با
# <code>&gamma;<sub>2</sub></code>).
# سپس خروجی آن را با تبدیل گامای مستقیم با
# <code>&gamma; = &gamma;<sub>1</sub> &sdot; &gamma;<sub>2</sub></code>
# مقایسه کنید و نشان دهید که نتایج یکسان هستند.
# </p>
# <p>
# <font face="B Mitra" size=5 color='e74c3c'>
# مقادیر دلخواه و مناسبی برای
# <code>&gamma;<sub>1</sub></code>
# و
# <code>&gamma;<sub>2</sub></code>
# انتخاب کنید. هر دو تصویر خروجی (متوالی و مستقیم) را در کنار هم نمایش دهید.
# </font>
# </p>
# </div>
# </font>

# %%
#TODO: Compare the results of cascaded and direct gamma transformations

# %% [markdown]
# <font face="B Mitra" size="4">
# <div dir="rtl">
# <h4>ج) اندازه‌گیری تفاوت با MSE</h4>
# <p>
# تفاوت بصری بین تصویر حاصل از دو تبدیل متوالی و تصویر حاصل از تبدیل معادل
# (<code>&gamma; = &gamma;<sub>1</sub> &sdot; &gamma;<sub>2</sub></code>)
# را با معیار
# <b>MSE</b>
# اندازه‌گیری کنید و
# <b>Heatmap</b>
#  اختلاف بین دو تصویر را رسم کنید.
# </p>
# <p>
# <font face="B Mitra" size=5 color='e74c3c'>
# آیا این دو تصویر کاملاً یکسانند؟ در صورت وجود تفاوت، علت آن را توضیح دهید.
# <br>
# <font face="B Mitra" size=4 color='lightgreen'>
# (راهنمایی: به خطاهای ناشی از گرد کردن مقادیر صحیح پیکسل‌ها و محدودیت دقت اعداد در بازه [0, 255] توجه کنید.)
# </font>
# </p>
# </div>
# </font>

# %%
#TODO: Measure the differences using MSE and plot the differences heatmap

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3>7. کشش هیستوگرام </h3>
#           <p>کشش هیستوگرام رویکردی است که دامنه شدت‌های موجود در تصویر را فراگیر می‌کند تا کنتراست را افزایش دهد؛ این کار با کشیدن انتهاهای هیستوگرام تصویر و توزیع دوباره شدت‌ها در کل دامنه ممکن انجام می‌شود. در مقابل، مسطح‌سازی هیستوگرام به فرآیند تنظیم توزیع شدت نور در هیستوگرام اطلاق می‌گردد به گونه‌ای که تمامی شدت‌ها بطور یکنواخت در دسترس باشند، این امر باعث بهبود کنتراست کلی در تصویر می‌شود.<br>
#             <br>
#             <font face="B Mitra" size=5 color='e74c3c'>
#     این روش را بر روی تصویر قبل اعمال کرده و تصویر نهایی را نمایش دهید. (پیاده سازی این روش باید توسط خود شما صورت بگیرد)
#         </font>
#         </p>
#     </div>
# </font>

# %%
#TODO: implement histogram stretching method

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#            <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام تصویر اولیه و نهایی را رسم کرده و تفاوت آن‌ها را تحلیل کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
#TODO: plot histograms

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3>8. مسطح‌سازی هیستوگرام </h3>
#           <p> مسطح‌سازی هیستوگرام به فرآیند تنظیم توزیع شدت نور در هیستوگرام اطلاق می‌گردد به گونه‌ای که تمامی شدت‌ها بطور یکنواخت در دسترس باشند، این امر باعث بهبود کنتراست کلی در تصویر می‌شود.<br>
#             <br>
#             <font face="B Mitra" size=5 color='e74c3c'>
#     این روش را بر روی تصویر قبل اعمال کرده و تصویر نهایی را نمایش دهید. (پیاده سازی این روش باید توسط خود شما صورت بگیرد)
#         </font>
#         </p>
#     </div>
# </font>

# %%
#TODO: implement histogram equalization method

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام تصویر اولیه و نهایی را رسم کرده و تفاوت آن‌ها را تحلیل کنید. همچنین در هر هیستوگرام تابع توزیع تجمعی(CDF) شدت‌ها را نیز رسم کنید.
#             </font>
#         </p>
#     </div>
#
# </font>

# %%
#TODO: plot histograms (Don't forget Cumulative Distribution Function)

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
#
# <font face="B Mitra" size=5 color='e74c3c'>
# در تئوری، Histogram Equalization باید هیستوگرام تصویر را یکنواخت کند.
# اما در عمل، هیستوگرام تصویر خروجی معمولاً کاملاً مسطح (Flat) نیست.
#
#  توضیح دهید چرا در تصاویر دیجیتال، Histogram Equalization الزاماً منجر به یک هیستوگرام کاملاً یکنواخت نمی‌شود.
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
#
# <font face="B Mitra" size=5 color='e74c3c'>
# فرض کنید تصویر دارای (N) پیکسل و (L) سطح شدت باشد. توضیح دهید چرا اگر
# <code>N &#8810; L</code>
# باشد، Equalization عملکرد ضعیف‌تری خواهد داشت.
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3> 9. تطبیق هیستوگرام (Histogram Matching / Specification)</h3>
#         <p>
#             تطبیق هیستوگرام فرآیندی است که در آن هیستوگرام یک تصویر به گونه‌ای تغییر داده می‌شود تا با هیستوگرام یک تصویر مرجع (Target) مشخص مطابقت داشته باشد. این روش در مواردی که نیاز به یکسان‌سازی شرایط نوری یا رنگی چند تصویر مختلف داریم (مانند پردازش تصاویر پزشکی) بسیار کاربرد دارد.
#             <br/>
#             <br/>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             الگوریتم تطبیق هیستوگرام را پیاده‌سازی کنید. الگوریتم را اعمال کرده و تصویر خروجی را نمایش دهید.
#             </font>
#             <br/>
#             <br/>
#             <font size=4, color="lightgreen">
#             <b>راهنمایی:</b> هدف این الگوریتم این است که مقادیر تابع توزیع تجمعی (CDF) تصویر مبدأ، شبیه به CDF تصویر مرجع شود. از آنجا که شدت‌های روشنایی مقادیری گسسته (مثلاً ۰ تا ۲۵۵) هستند، یافتن برابری مطلق همیشه ممکن نیست؛ بنابراین باید از یک جدول جستجو (LUT - Look Up Table) استفاده کنید.
#             <br/>
#             <i>نحوه ساخت LUT:</i> یک آرایه خالی به طول ۲۵۶ ایجاد کنید. سپس برای هر شدت روشنایی در تصویر مبدأ، در آرایه CDF تصویر مرجع جستجو کنید و سطح روشنایی‌ای را بیابید که مقدار CDF آن <b>نزدیک‌ترین مقدار</b> به CDF مبدأ باشد. این سطح روشنایی جدید را در اندیس متناظر در LUT ذخیره کنید. در نهایت، با استفاده از این جدول، مقادیر پیکسل‌های تصویر مبدأ را با مقادیر جدید جایگزین (نگاشت) کنید.
#             </font>
#         </p>
#     </div>
# </font>

# %%
source_image = read_image_from_url("https://i.ibb.co/2t2Z20K/house1.jpg", cv2.IMREAD_GRAYSCALE)
ref_image = read_image_from_url("https://i.ibb.co/7C0HcYV/B.jpg", cv2.IMREAD_GRAYSCALE)

#TODO: implement histogram specification method and show the source, reference and output images

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             هیستوگرام و تابع توزیع تجمعی (CDF) هر سه تصویر (مبدا، مرجع و خروجی) را رسم کرده و نتیجه را تحلیل کنید.
#             </font>
#         </p>
#     </div>
# </font>

# %%
#TODO: Plot Histograms and CDFs

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3> 10. مسطح‌سازی هیستوگرام تصویر رنگی</h3>
#         <p>
#             اعمال مستقیم مسطح‌سازی هیستوگرام روی کانال‌های R، G و B به صورت مجزا در تصاویر رنگی، معمولاً منجر به تغییرات ناخواسته و به هم ریختگی رنگ‌ها (Color Shift) می‌شود. برای بهبود کنتراست تصاویر رنگی بدون آسیب به اطلاعات رنگ، تصویر را به فضای رنگی HSV برده و مسطح‌سازی را صرفاً روی کانال روشنایی (V یا Value) اعمال می‌کنیم.
#             <br/>
#             <br/>
#             <font face="B Mitra" size=5 color='e74c3c'>
#              یک بار مسطح‌سازی را به صورت مجزا روی کانال‌های R و G و B اعمال کرده و نتیجه را ترکیب کنید. بار دیگر تصویر را به فضای HSV برده، کانال V را مسطح‌سازی کنید و سپس تصویر را به RGB بازگردانید. هر دو خروجی را در کنار تصویر اصلی نمایش دهید.
#             </font>
#             <br/>
#             <br/>
#             <font size=4, color="lightgreen">
#             <b>راهنمایی:</b>
#             <br/>
#             فضای رنگی HSV از سه مؤلفه <b>فام (Hue)</b>، <b>اشباع (Saturation)</b> و <b>روشنایی (Value)</b> تشکیل شده است. این فضا اطلاعات شدت نور (V) را کاملاً از ماهیت رنگ (H و S) جدا می‌کند.
#             <br/>
#             می‌توانید برای رفت و برگشت بین دو فضا، به سادگی از توابع آماده (مانند <code>cv2.cvtColor</code> در OpenCV و فلگ‌های <code>COLOR_BGR2HSV</code> و <code>COLOR_HSV2BGR</code>) استفاده کنید.
#             </font>
#         </p>
#     </div>
# </font>

# %%
# Load Color Image
image = read_image_from_url("https://cdn.imgurl.ir/uploads/s439125_breaking-bad-pizza.jpg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#TODO: perform histogram equalization on each RGB channel independently

#TODO: perform histogram equalization on the V-channel of the HSV

#TODO: show the original and processed images

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             تفاوت بصری دو روش فوق را تحلیل کنید و توضیح دهید چرا روش دوم رنگ‌ها را طبیعی‌تر حفظ می‌کند.
#             </font>
#         </p>
#     </div>
# </font>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3> 11. انتقال پالت رنگی با تطبیق هیستوگرام (فضای RGB)</h3>
#         <p>
#             برای انتقال توزیع رنگی یک تصویر مرجع به یک تصویر مبدا، شاید اولین ایده‌ای که به ذهن برسد، اعمال الگوریتم <b>تطبیق هیستوگرام</b> روی تصاویر رنگی باشد.
#             <br/>
#             <br/>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             تصویر مبدا و مرجع را بارگذاری کنید. کانال‌های R، G و B آن‌ها را جدا کرده و الگوریتم تطبیق هیستوگرام را به صورت مستقل روی هر کانال اعمال کنید. سپس کانال‌ها را ترکیب کرده و نتیجه را در کنار تصاویر اصلی نمایش دهید.
#             </font>
#         </p>
#     </div>
# </font>

# %%
# Load source and style (reference) images
source_img = read_image_from_url("https://i.ibb.co/ns1RV45G/tree.jpg") 
source_img = cv2.cvtColor(source_img, cv2.COLOR_BGR2RGB)
style_img = read_image_from_url("https://i.ibb.co/6J0Hn9qB/painting.jpg")
style_img = cv2.cvtColor(style_img, cv2.COLOR_BGR2RGB)

#TODO: perform histogram matching on each RGB channel independently and show the source, style and output images

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <h3> انتقال رنگ (Color Transfer) در فضای رنگی LAB</h3>
#         <p>
#             همان‌طور که در سوال قبل مشاهده کردید، استفاده از تطبیق هیستوگرام روی کانال‌های RGB نتایج نامطلوبی در پی دارد. برای حل این مشکل، تصویر را به فضای رنگی LAB انتقال می‌دهیم. در این فضا، روشنایی (L) از اطلاعات رنگ (a و b) کاملاً جداست و کانال‌های رنگی کمترین وابستگی را به هم دارند.
#             <br/>
#             با تطبیق میانگین و انحراف معیار پیکسل‌ها در این فضا، می‌توانیم پالت رنگی را با فرمول زیر برای هر کانال انتقال دهیم:
#         </p>
#     </div>
# </font>
#
# $$Out = \frac{\sigma_{ref}}{\sigma_{src}} (In - \mu_{src}) + \mu_{ref}$$
#
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             الگوریتم انتقال رنگ فوق (معروف به روش Reinhard) را پیاده‌سازی کنید و پالت رنگی تصویر مرجع را به مبدا انتقال دهید.
#             </font>
#             <br/>
#             <br/>
#             <b> آشنایی با فضای رنگی LAB :</b>
#             <br/>
#             فضای رنگی CIELAB (یا به اختصار LAB) بر اساس نحوه درک چشم و مغز انسان از رنگ‌ها طراحی شده است. برخلاف فضای RGB که در آن رنگ و نور با هم ترکیب شده‌اند، LAB این دو مفهوم را کاملاً از هم جدا می‌کند. این فضا شامل سه مؤلفه است:
#             <ul style="margin-top: 5px;">
#                 <li><b>کانال L (Lightness):</b> نشان‌دهنده شدت روشنایی است (از ۰ برای سیاه مطلق تا ۱۰۰ برای سفید خالص).</li>
#                 <li><b>کانال a:</b> بیانگر طیف رنگی بین <b>سبز</b> (مقادیر منفی) تا <b>قرمز/ارغوانی</b> (مقادیر مثبت) است.</li>
#                 <li><b>کانال b:</b> بیانگر طیف رنگی بین <b>آبی</b> (مقادیر منفی) تا <b>زرد</b> (مقادیر مثبت) است.</li>
#             </ul>
#             <i>چرا از LAB استفاده می‌کنیم؟</i> مستقل بودن این سه کانال به ما اجازه می‌دهد که رنگ و نور یک تصویر را بدون ایجاد به هم ریختگی تغییر دهیم.
#             <br/>
#             <br/>
#         </p>
#     </div>
# </font>

# %%
# Convert images to LAB color space
src_lab = cv2.cvtColor(source_img, cv2.COLOR_RGB2LAB).astype(np.float64)
ref_lab = cv2.cvtColor(style_img, cv2.COLOR_RGB2LAB).astype(np.float64)

#TODO: perform histogram matching on each LAB channel independently and show the source, style and output images

# %% [markdown]
# <font face="B Mitra" size=4>
#     <div dir="rtl">
#         <p>
#             <font face="B Mitra" size=5 color='e74c3c'>
#             تفاوت بصری دو روش فوق را تحلیل کنید و توضیح دهید چرا روش دوم رنگ‌ها را طبیعی‌تر حفظ می‌کند.
#             </font>
#         </p>
#     </div>
# </font>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
# <hr>

# %% [markdown]
# <font face="B Mitra" size="4">
#     <div dir="rtl">
#         <h3>12. آستانه گیری</h3>
#         <p>
#             <b>Thresholding</b> یا آستانه‌گیری یک تبدیل تکه‌ای خطی است که در آن شدت پیکسل‌ها بر اساس یک آستانه مشخص تغییر می‌کند. به این صورت که اگر مقدار پیکسل از آستانه کمتر باشد برابر ۰ و در غیر این صورت ۲۵۵ در نظر گرفته می‌شود.
#         </p>
#         <p>
#             در تبدیل تکه‌ای آستانه‌گیری، برای هر پیکسل در تصویر، از رابطه زیر استفاده می‌شود:
#         </p>
#         <p>
#             <code>V<sub>out</sub> = 0 if V<sub>in</sub> < T else 255</code>
#         </p>
#         <p>
#             که در آن:
#             <ul>
#                 <li><code>V<sub>in</sub></code>: مقدار ورودی (شدت پیکسل)</li>
#                 <li><code>V<sub>out</sub></code>: مقدار خروجی (شدت پیکسل جدید)</li>
#                 <li><code>T</code>: مقدار آستانه است که برای جداسازی نواحی روشن و تاریک تصویر استفاده می‌شود.</li>
#             </ul>
#         </p>
#         <br>
#         <h3>آستانه‌گیری محلی:</h3>
#         <p>
#             در آستانه‌گیری محلی (Local Thresholding) برخلاف آستانه‌گیری کلی که از یک آستانه ثابت برای تمام پیکسل‌ها استفاده می‌کند، هر پیکسل بر اساس شدت پیکسل‌های اطراف خود آستانه‌گیری می‌شود. در این روش برای تعیین حد آستانه هر پیکسل از پیکسل‌های همسایه (در همه جهت‌ها) کمک می‌گیرند و حد آستانه را تعریف می‌کنند. به این صورت که در ابتدا یک تعداد پیکسل همسایه در یک پنجره انتخاب می شود، و سپس میانگین مقدار شدت روشنایی پیکسلهای همسایه محاسبه می شود و بر اساس آن تصمیم گرفته می‌شود که پیکسل مورد نظر به ۲۵۵ یا ۰ تبدیل شود.
#         </p>
#         <br>
#         <font face="B Mitra" size=5 color='e74c3c'>
#         در این تمرین، شما باید آستانه‌گیری محلی را پیاده‌سازی کنید: به این صورت که برای هر پیکسل میانگین شدت پیکسل‌های اطراف را محاسبه کرده(window_size را برابر ۱۰ در نظر بگیرید) و اگر شدت پیکسل موردنظر از ۸۵ درصد این میانگین کمتر بود مقدار آن برابر ۰ و در غیر این صورت برابر ۲۵۵ در نظر گرفته شود. در نهایت تصویر اصلاح‌شده را نمایش دهید.
#         </font>
#     </div>
# </font>

# %%
image = read_image_from_url("https://i.ibb.co/W6H4zhW/thrsh.jpg", cv2.IMREAD_GRAYSCALE)

#TODO: show the image

# %%
#TODO: implement local thresholding method and show the result

# %% [markdown]
# <div dir=rtl>
#
# <font face="B Mitra" size=5 color='e74c3c'>
#  توضیح دهید چرا این روش نسبت به Global Thresholding محاسبات بیشتری نیاز دارد.
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
#
# <font face="B Mitra" size=5 color='e74c3c'>
# اگر اندازه پنجره (window_size) بسیار کوچک انتخاب شود چه مشکلی ایجاد می‌شود؟
#
# اگر اندازه پنجره بسیار بزرگ انتخاب شود چه مشکلی ایجاد می‌شود؟
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
#
# <font face="B Mitra" size=5 color='e74c3c'>
# آیا Local Thresholding همیشه از Global Thresholding بهتر است؟ توضیح دهید.
# </font>
# </div>

# %% [markdown]
# <div dir=rtl>
# <p>
# <font face="B Mitra" size=5, color='cyan'>
# لطفا پاسخ خود را اینجا بنویسید.
# </p>
# </font>
# </div>
